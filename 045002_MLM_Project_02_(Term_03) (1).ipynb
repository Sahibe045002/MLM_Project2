# %% [markdown]
# **TOPIC**: Customer segmentation by Pizza prefrences
#
# **Submitted by**: Sahibe Aalam -045002
#
# **Submitted to**: Prof. Amarnath Mitra
#
#
#
#
# Project Title: Customer segmentation by Pizza prefrences.
#
# #Project Objectives:
#
# PO1 | PS1: Classification of Consumer Data into Segments | Clusters | Classes using Supervised Learning Classification Algorithms 1.2. PO2 | PS2: Determination of an Appropriate Classification Model 1.3. PO3 | PS3: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification
#
# # Description of Data
#
#  Data Size: 4691.375 KB
#  Data Shape | Dimension: 12 Number of Variables | 50040 Number of Records
# [50040 rows x 12 columns]
#
#  Data Source (https://github.com/Sahibe045002/Machine-learning-11/blob/main/pizza_sales.csv)
#
# # Description of Variables
#
#
# **Index Variable:**
#
# pizza_id
#
# order_id
#
# **Categorical Variables or Features (CV):**
#
# pizza_name
#
# pizza_size
#
# pizza_category
#
# **Categorical Variables or Features - Nominal Type:**
#
# pizza_name
#
# **Categorical Variables or Features - Ordinal Type:** Nil
#
# **Non-Categorical Variables or Features:**
#
# pizza_id
#
# order_id
#
# pizza_name_id
#
# quantity
#
# order_date
#
# order_time
#
# unit_price
#
# total_price
#
# pizza_ingredients
#
#
# #  Descriptive Statistics
#
# ##Descriptive Statistics: Categorical Variables or Features
#
# ### Count | Frequency Statistics:
# The count or frequency statistics show the number of occurrences of each pizza name in the dataset. For example, "The Classic Deluxe Pizza" appears 2488 times, "The Barbecue Chicken Pizza" appears 2455 times, and so on.
#
# ### Proportion (Relative Frequency) Statistics:
#
# The proportion statistics represent the relative frequency of each pizza name compared to the total number of pizza orders. This is calculated by dividing the count of each pizza name by the total number of pizza orders. For instance, "The Classic Deluxe Pizza" represents approximately 4.97% of all pizza orders, "The Barbecue Chicken Pizza" represents approximately 4.91%, and so forth.
#
# # Descriptive Statistics: Non-Categorical Variables or Features
#
# ###Measures of Central Tendency:
#
# - For `quantity`, the mean value is approximately 1.02, indicating that the average quantity of pizzas ordered is slightly above 1.
#
# - For `unit_price`, the mean value is approximately 16.49, suggesting that the average price of a single pizza unit is around $16.49.
#
# - For `total_price`, the mean value is approximately 16.83, implying that the average total price of an order is approximately $16.83.
#
# ###Measures of Dispersion:
#
# - For `quantity`, the standard deviation is approximately 0.15, suggesting that the quantity of pizzas ordered varies slightly around the mean.
# - For `unit_price`, the standard deviation is approximately 3.62, indicating that there is significant variability in pizza unit prices across orders.
# - For `total_price`, the standard deviation is approximately 4.46, implying that the total price of orders varies noticeably around the mean.
#
# ### Correlation Statistics (with Test of Correlation):
#
# - The correlation coefficient between `quantity` and `total_price` is approximately 0.51, indicating a moderate positive correlation. This suggests that as the quantity of pizzas ordered increases, the total price of the order tends to increase as well.
# - The correlation coefficient between `unit_price` and `total_price` is approximately 0.83, indicating a strong positive correlation. This suggests that as the unit price of pizzas increases, the total price of the order also tends to increase significantly.
#
#
# # Analysis of Data
#
# ### Missing Data Statistics:
# - **Number of Records with Missing Data:** 0
#
# ### Missing Data Treatment:
# - **No Records have Missing Data**
#
# ### Analysis:
#   **Data Completeness:** The dataset appears to be complete, with no missing values observed across any records.
#
# #Outlier Statistics and Treatment
#
# 1. **Number of Outliers:**
#    - For `pizza_id` and `order_id`, there are no outliers detected, meaning that all values fall within a reasonable range without any extreme deviations.
#    - However, for `quantity`, `unit_price`, and `total_price`, outliers are detected. Specifically, there are 1006 outliers in `quantity`, 28 outliers in `unit_price`, and 713 outliers in `total_price`.
#
# 2. **Interpretation:**
#    - Outliers in `quantity`, `unit_price`, and `total_price` suggest that there are some observations in the dataset with unusually high or low values compared to the majority of the data.
#    - For `quantity`, it's common to have outliers if there are bulk orders or unusually small orders.
#    - Outliers in `unit_price` could indicate pricing errors or special pricing for certain items.
#    - Outliers in `total_price` might be due to large orders or errors in calculating the total price.
#
#
#
# ###  Classification Model Performance: Time & Memory Statistics
#
#
#
# #### Base Model (Decision Tree)
#
# 1. Decision Tree Model:
#
# Model Parameters:
# Max Depth: 3
# Random State: 45040
# Model Performance:
# Training Set:
# Precision, Recall, and F1-Score: 1.00 for all classes
# Accuracy: 1.00
# Testing Set:
# Precision, Recall, and F1-Score: 0.99 for all classes
# Accuracy: 0.99
#
# Implications:
# The Decision Tree model exhibits excellent performance, achieving perfect classification on the training set and high accuracy on the testing set.
# The model's simplicity and interpretability make it suitable for scenarios where understanding the decision-making process is important.
#
# 2. KNN:
#
# The KNN classifier achieved the following accuracies for different values of k on the testing dataset:
# For k=9: 0.9772
# For k=11: 0.9775
# For k=13: 0.9776
# For k=15: 0.9768
# For k=17: 0.9762
#
#  Classification Report:
# The classification report for the KNN model on the testing dataset shows the precision, recall, and F1-score for each class, along with the macro and weighted averages.
#
# Confusion Matrix:
# The confusion matrix provides a detailed breakdown of the model's predictions versus the actual labels for each class.
#
# Feature Importance Analysis:
#
# No Feature Importance:
# Unlike some other models like Decision Trees or Random Forests, KNN does not inherently provide feature importance.
#
# Cross-Validation Analysis:
#  Cross-Validation Scores:
# Cross-validation scores were computed to assess the model's generalization performance.
# The mean cross-validation score was approximately 0.9923, indicating high performance and generalizability.
#
# #### Comparison Models
# - **Logistic Regression**
# - **Support Vector Machine**
# - **K Nearest Neighbour (KNN)**
#
# ###  Classification Model Performance: Time & Memory Statistics
#
# #### Base Model (Decision Tree)
# - Training Time: 48.9 ms
# - Prediction Time (Testing Subset): 7.98 ms
# - Memory Usage: N/A
#
# #### Comparison Models
#
#
# - **K Nearest Neighbour (KNN)**
#   - Training Time: 60.2 ms
#   - Prediction Time (Testing Subset): 50.5 ms
#   - Memory Usage: N/A
#
#
# ###  Variable or Feature Analysis
#
# #### Base Model (Decision Tree) and Comparison Models
# - **List of Relevant or Important Variables or Features and their Thresholds:**
#   - **Decision Tree:**
#     - 1. pizza_name_id (importance: 0.803)
#     - 2. unit_price (importance: 0.196)
#   - **Logistic Regression, Support Vector Machine, KNN:**
#     - N/A
#
# - **List of Non-Relevant or Non-Important Variables or Features:**
#   - **Decision Tree, Logistic Regression, Support Vector Machine, KNN:**
#     - 1. pizza_size
#     - 2. order_id
#     - 3. total_price
#
# ###  Managerial Insights
#
# ####  Appropriate Model
# Based on the provided analysis, the K Nearest Neighbour (KNN) model demonstrates the highest accuracy among the compared models, achieving an accuracy of 0.9773 on the testing subset.
#
# ####  Relevant or Important Variables or Features (Given the Appropriate Model)
# The relevant variables identified for the Decision Tree model are `pizza_name_id` and `unit_price`, which have demonstrated significant importance in the classification task. However, for Logistic Regression, Support Vector Machine, and KNN, no specific relevant variables were identified based on the provided information.
#
#
# #Managerial Implication
#
# The selection of an appropriate classification model, such as K Nearest Neighbour (KNN), can significantly impact decision-making processes in various domains. For instance, in marketing, accurately segmenting consumers into different categories based on their preferences or behaviors can enable targeted marketing strategies, leading to improved customer engagement and higher conversion rates. Additionally, understanding the importance of different variables or features in the classification task can guide resource allocation for data collection and feature engineering efforts, ensuring that the most relevant information is considered in the predictive modeling process. Therefore, leveraging the insights gained from model performance evaluation and variable analysis can facilitate more effective decision-making and resource optimization in business operations.
#
# Optimal k Value Selection:
# Based on the analysis of accuracy for different values of k, it's recommended to choose k=13 as it yields the highest accuracy among the tested values.
#
# Generalizability:
# The KNN model demonstrates high accuracy and generalizability, making it suitable for classifying new instances based on their proximity to existing data points.
#
# Limitations:
# KNN's performance might degrade in high-dimensional spaces or with large datasets due to computational inefficiency.
# The model's performance heavily depends on the choice of the distance metric and the value of k.
#
# Overall, the KNN model shows strong performance on the provided dataset, especially when k=13, making it a viable choice for classification tasks in similar contexts.
#
#
#
#
#
# #References
#
# Prof. Amarnath Mitra
#
# Chat GPT.
#
# Kaggle

# %%
import sys

# Install necessary packages
# !{sys.executable} -m pip install pandas scikit-learn matplotlib

# %%
# @title  { display-mode: "form" }
# Load IPython extension for measuring time
# !pip install ipython-autotime
# %reload_ext autotime

# Load IPython extension for memory profiling
# !pip install memory-profiler
# %reload_ext memory_profiler

## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree


## Data Preprocessing Libraries
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import f1_score

## Machine Learning Models and Evaluation Metrics
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline

# Measure memory and RAM usage
# %memit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.0 MB/s eta 0:00:00
# ...
# peak memory: 206.62 MiB, increment: 0.27 MiB
# time: 17.8 s (started: 2024-04-13 12:57:09 +00:00)

# %%
import pandas as pd

# GitHub CSV file URL
url = 'https://raw.githubusercontent.com/Sahibe045002/Machine-learning-11/main/pizza_sales.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Display the first few rows of the DataFrame to verify that it has been read successfully
print(df.head())
# Out:
#    pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0         1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1         2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2         3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3         4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4         5         2     mexicana_m         1  01-01-2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
# Subset of Categorical Variables
df_cat = df[['pizza_category','pizza_name_id','pizza_size']]
df_cat
# Out:
#       pizza_category   pizza_name_id pizza_size
# 0            Classic      hawaiian_m          M
# 1            Classic   classic_dlx_m          M
# 2             Veggie   five_cheese_l          L
# 3            Supreme     ital_supr_l          L
# 4             Veggie      mexicana_m          M
# ...              ...             ...        ...
# 50035        Supreme    prsc_argla_m          L
# 50036         Veggie   five_cheese_l          S
# 50037        Classic  peppr_salami_l          S
# 50038        Chicken  green_garden_m          L
# 50039         Veggie      mexicana_m          L
#
# [50040 rows x 3 columns]
# time: 280 ms (started: 2024-04-13 12:57:38 +00:00)

# %%
# Subset of Non-Categorical Variables
df_noncat = df[['order_id', 'unit_price', 'total_price']]
df_noncat
# Out:
#        order_id  unit_price  total_price
# 0             1       13.25        13.25
# 1             2       16.00        16.00
# 2             2       18.50        18.50
# 3             2       20.75        20.75
# 4             2       16.00        16.00
# ...         ...         ...          ...
# 50035     22766       20.25        20.25
# 50036     22767       12.00        12.00
# 50037     22768       12.00        12.00
# 50038     22769       20.75        20.75
# 50039     22770       21.00        21.00
#
# [50040 rows x 3 columns]
# time: 64.9 ms (started: 2024-04-13 12:57:43 +00:00)

# %%
# Create subplots with 2 rows and 3 columns
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Plot pie charts for each categorical variable
variables = ['pizza_category','pizza_name_id','pizza_size']
stats_dict = {}

for i, var in enumerate(variables):
    row = i // 3
    col = i % 3

    stats_dict[var] = pd.concat([df[var].value_counts(), df[var].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()

    axes[row, col].pie(stats_dict[var]['count'], labels=stats_dict[var][var], autopct='%0.2f%%')
    axes[row, col].set_title(f'{var} Pie Plot')
    axes[row, col].axis('equal')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# time: 3.83 s (started: 2024-04-13 10:30:30 +00:00)

# %%
# Dataframe Information (Provide Information on Missing Data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50040 entries, 0 to 50039
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           50040 non-null  int64
#  1   order_id           50040 non-null  int64
#  2   pizza_name_id      50040 non-null  object
#  3   quantity           50040 non-null  int64
#  4   order_date         50040 non-null  object
#  5   order_time         50040 non-null  object
#  6   unit_price         50040 non-null  float64
#  7   total_price        50040 non-null  float64
#  8   pizza_size         50040 non-null  object
#  9   pizza_category     50040 non-null  object
#  10  pizza_ingredients  50040 non-null  object
#  11  pizza_name         50040 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.6+ MB
# time: 80.3 ms (started: 2024-04-13 10:31:03 +00:00)

# %%
# Variable-wise Missing Data Information
variable_missing_data = df.isna().sum(); variable_missing_data
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64
# time: 59 ms (started: 2024-04-13 11:01:28 +00:00)

# %%
# Record-wise Missing Data Information (Top 50000)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(50000);
record_missing_data.describe()
# Out:
# count    50000.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# dtype: float64
# time: 64.6 ms (started: 2024-04-13 11:01:32 +00:00)

# %%
from sklearn.preprocessing import OrdinalEncoder
# Dataset Used : df_cat
# Using Scikit Learn : Ordinal Encoder (Superior)
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat)
df_cat_oe = pd.DataFrame(oe_fit, columns=df_cat.columns);
#Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_oe
# Out:
#        pizza_category  pizza_name_id  pizza_size
# 0                 1.0           27.0         1.0
# 1                 1.0           18.0         1.0
# 2                 3.0           20.0         0.0
# 3                 2.0           32.0         0.0
# 4                 3.0           42.0         1.0
# ...               ...            ...         ...
# 50035             2.0           57.0         0.0
# 50036             3.0           20.0         2.0
# 50037             1.0           53.0         2.0
# 50038             0.0           24.0         0.0
# 50039             3.0           42.0         0.0
#
# [50040 rows x 3 columns]
# time: 55.7 ms (started: 2024-04-13 11:02:27 +00:00)

# %%
#Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat[['order_id', 'unit_price', 'total_price']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat.columns);
df_noncat_minmax_norm
# Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scalera
# Out:
#        order_id  unit_price  total_price
# 0      0.000000    0.133588     0.047782
# 1      0.000044    0.238550     0.085324
# 2      0.000044    0.333969     0.119454
# 3      0.000044    0.419847     0.150171
# 4      0.000044    0.238550     0.085324
# ...         ...         ...          ...
# 50035  0.999824    0.400763     0.143345
# 50036  0.999868    0.085878     0.030717
# 50037  0.999912    0.085878     0.030717
# 50038  0.999956    0.419847     0.150171
# 50039  1.000000    0.429389     0.153584
#
# [50040 rows x 3 columns]
# time: 30.5 ms (started: 2024-04-13 11:02:34 +00:00)

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_oe.copy();
df_cat_ppd # Preferred Data Subset
# Out:
#        pizza_category  pizza_name_id  pizza_size
# 0                 1.0           27.0         1.0
# 1                 1.0           18.0         1.0
# 2                 3.0           20.0         0.0
# 3                 2.0           32.0         0.0
# 4                 3.0           42.0         1.0
# ...               ...            ...         ...
# 50035             2.0           57.0         0.0
# 50036             3.0           20.0         2.0
# 50037             1.0           53.0         2.0
# 50038             0.0           24.0         0.0
# 50039             3.0           42.0         0.0
#
# [50040 rows x 3 columns]
# time: 29.5 ms (started: 2024-04-13 11:02:36 +00:00)

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_minmax_norm.copy();
df_noncat_ppd # Preferred Data Subset
# Out:
#        order_id  unit_price  total_price
# 0      0.000000    0.133588     0.047782
# 1      0.000044    0.238550     0.085324
# 2      0.000044    0.333969     0.119454
# 3      0.000044    0.419847     0.150171
# 4      0.000044    0.238550     0.085324
# ...         ...         ...          ...
# 50035  0.999824    0.400763     0.143345
# 50036  0.999868    0.085878     0.030717
# 50037  0.999912    0.085878     0.030717
# 50038  0.999956    0.419847     0.150171
# 50039  1.000000    0.429389     0.153584
#
# [50040 rows x 3 columns]
# time: 24.9 ms (started: 2024-04-13 11:02:38 +00:00)

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd);
df_ppd # Pre-Processed Dataset
# Out:
#        pizza_category  pizza_name_id  pizza_size  order_id  unit_price  \
# 0                 1.0           27.0         1.0  0.000000    0.133588
# 1                 1.0           18.0         1.0  0.000044    0.238550
# 2                 3.0           20.0         0.0  0.000044    0.333969
# 3                 2.0           32.0         0.0  0.000044    0.419847
# 4                 3.0           42.0         1.0  0.000044    0.238550
# ...               ...            ...         ...       ...         ...
# 50035             2.0           57.0         0.0  0.999824    0.400763
# 50036             3.0           20.0         2.0  0.999868    0.085878
# 50037             1.0           53.0         2.0  0.999912    0.085878
# 50038             0.0           24.0         0.0  0.999956    0.419847
# 50039             3.0           42.0         0.0  1.000000    0.429389
#
#        total_price
# 0         0.047782
# 1         0.085324
# 2         0.119454
# 3         0.150171
# ...

# %%
df1 = df_ppd.copy();
df1
# Out:
#        pizza_category  pizza_name_id  pizza_size  order_id  unit_price  \
# 0                 1.0           27.0         1.0  0.000000    0.133588
# 1                 1.0           18.0         1.0  0.000044    0.238550
# 2                 3.0           20.0         0.0  0.000044    0.333969
# 3                 2.0           32.0         0.0  0.000044    0.419847
# 4                 3.0           42.0         1.0  0.000044    0.238550
# ...               ...            ...         ...       ...         ...
# 50035             2.0           57.0         0.0  0.999824    0.400763
# 50036             3.0           20.0         2.0  0.999868    0.085878
# 50037             1.0           53.0         2.0  0.999912    0.085878
# 50038             0.0           24.0         0.0  0.999956    0.419847
# 50039             3.0           42.0         0.0  1.000000    0.429389
#
#        total_price
# 0         0.047782
# 1         0.085324
# 2         0.119454
# 3         0.150171
# ...

# %%
df1.columns
# Out:
# Index(['pizza_category', 'pizza_name_id', 'pizza_size', 'order_id',
#        'unit_price', 'total_price'],
#       dtype='object')
# time: 3.28 ms (started: 2024-04-13 11:02:49 +00:00)

# %%
df1_inputs = df1[['pizza_name_id', 'pizza_size', 'order_id',
       'unit_price', 'total_price']];
df1_inputs

df1_output = df1[['pizza_category']];
df1_output

df1_inputs_names = df1_inputs.columns;
df1_inputs_names
df1_output_labels = df1_output['pizza_category'].unique().astype(str);
df1_output_labels
# Out:
# array(['1.0', '3.0', '2.0', '0.0'], dtype='<U32')
# time: 13.7 ms (started: 2024-04-13 11:02:53 +00:00)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45040)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(df1_inputs, df1_output):
    df1_inputs_train, df1_inputs_test = df1_inputs.iloc[train_index], df1_inputs.iloc[test_index]
    df1_output_train, df1_output_test = df1_output.iloc[train_index], df1_output.iloc[test_index]
# Out:
# time: 226 ms (started: 2024-04-13 11:02:56 +00:00)

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45040, max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(df1_inputs_train, df1_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45040)
# time: 48.9 ms (started: 2024-04-13 11:02:59 +00:00)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(df1_inputs_names)); print(dtc_model_rules)
# Out:
# |--- pizza_name_id <= 16.50
# |   |--- unit_price <= 0.09
# |   |   |--- order_id <= 0.94
# |   |   |   |--- class: 1.0
# |   |   |--- order_id >  0.94
# |   |   |   |--- class: 1.0
# |   |--- unit_price >  0.09
# |   |   |--- unit_price <= 0.48
# |   |   |   |--- class: 0.0
# |   |   |--- unit_price >  0.48
# |   |   |   |--- class: 2.0
# |--- pizza_name_id >  16.50
# |   |--- pizza_name_id <= 52.50
# |   |   |--- pizza_name_id <= 43.50
# |   |   |   |--- class: 3.0
# |   |   |--- pizza_name_id >  43.50
# |   |   |   |--- class: 1.0
# |   |--- pizza_name_id >  52.50
# |   |   |--- pizza_name_id <= 70.50
# |   |   |   |--- class: 2.0
# |   |   |--- pizza_name_id >  70.50
# |   |   |   |--- class: 3.0
#
# time: 2 ms (started: 2024-04-13 11:03:01 +00:00)

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': df1_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#          feature  importance
# 0  pizza_name_id       0.803
# 3     unit_price       0.196
# 1     pizza_size       0.000
# 2       order_id       0.000
# 4    total_price       0.000
# time: 12.7 ms (started: 2024-04-13 11:03:03 +00:00)

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(df1_inputs_train); dtc_model_predict
# Out:
# array([3., 3., 3., ..., 3., 3., 1.])
# time: 10.4 ms (started: 2024-04-13 11:03:06 +00:00)

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(df1_inputs_test); dtc_predict
# Out:
# array([3., 3., 2., ..., 3., 3., 2.])
# time: 7.98 ms (started: 2024-04-13 11:03:08 +00:00)

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(df1_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(df1_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.60      0.71      8909
#          1.0       0.98      0.47      0.63     11998
#          2.0       0.80      0.68      0.73      9652
#          3.0       0.47      0.99      0.64      9473
#
#     accuracy                           0.67     40032
#    macro avg       0.78      0.68      0.68     40032
# weighted avg       0.79      0.67      0.67     40032
#
# time: 147 ms (started: 2024-04-13 11:03:10 +00:00)

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(df1_output_test, dtc_predict)); dtc_predict_conf_mat
dtc_predict_perf = classification_report(df1_output_test, dtc_predict); print(dtc_predict_perf)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.60      0.70      2228
#          1.0       0.99      0.48      0.64      2999
#          2.0       0.79      0.66      0.72      2413
#          3.0       0.47      0.98      0.63      2368
#
#     accuracy                           0.67     10008
#    macro avg       0.77      0.68      0.67     10008
# weighted avg       0.79      0.67      0.67     10008
#
# time: 49.2 ms (started: 2024-04-13 11:03:12 +00:00)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=df1_inputs_names, class_names=df1_output_labels, rounded=True, filled=True, fontsize=7)

# Show the plot
plt.show()
# Out:
# time: 683 ms (started: 2024-04-13 11:03:14 +00:00)

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_predict_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()
# Out:
# time: 287 ms (started: 2024-04-13 11:03:17 +00:00)

# %% [markdown]
# **KNN**

# %%
# Specify the number of neighbors (k)
k = 7

# Initialize KNN classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Fit the KNN model using the training data
knn.fit(df1_inputs_train, df1_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=7)
# time: 60.2 ms (started: 2024-04-13 11:03:26 +00:00)

# %%
# Make predictions using the testing data
y_pred = knn.predict(df1_inputs_test)
# Out:
# time: 682 ms (started: 2024-04-13 11:03:29 +00:00)

# %%
# Calculate accuracy
accuracy = accuracy_score(df1_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(df1_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(df1_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.9773181454836131
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.97      2228
#          1.0       0.98      0.98      0.98      2999
#          2.0       0.98      0.98      0.98      2413
#          3.0       0.98      0.97      0.97      2368
#
#     accuracy                           0.98     10008
#    macro avg       0.98      0.98      0.98     10008
# weighted avg       0.98      0.98      0.98     10008
#
# Confusion Matrix:
# [[2176   20   14   18]
#  [  24 2941   11   23]
#  [  18   20 2359   16]
#  [  25   18   20 2305]]
# time: 50.5 ms (started: 2024-04-13 11:03:31 +00:00)

# %% [markdown]
# The precision, recall, and F1-score for each class (0.0, 1.0, 2.0, and 3.0) are all quite high, ranging from 0.97 to 0.98, which suggests that the model performs well in distinguishing between different pizza categories. The weighted average F1-score is also 0.98, indicating overall good performance across all classes.

# %%
k_values = [9, 11, 13, 15,17]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(df1_inputs_train, df1_output_train)  # Use your training data here
    y_pred = knn.predict(df1_inputs_test)  # Use your testing data here
    accuracy = accuracy_score(df1_output_test, y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=9: 0.9772182254196643
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 0.9775179856115108
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=13: 0.9776179056754596
# ...

# %% [markdown]
# Accuracy for Different k Values:
#
# For k=9: 0.9772
# For k=11: 0.9775
# For k=13: 0.9776
# For k=15: 0.9768
# For k=17: 0.9762
# Observation:

# %%
# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(df1_output_test, y_pred)
# Out:
# time: 224 ms (started: 2024-04-13 11:03:38 +00:00)

# %% [markdown]
# Observations based on the output of the K Nearest Neighbors (KNN) model:
#
# 1. **Model Configuration**:
#    - The KNN model is configured with 7 neighbors initially.
#    - Accuracy for the initial configuration is 0.9773, indicating that the model achieved a high level of accuracy in classifying the data.
#
# 2. **Classification Report**:
#    - Precision, recall, and F1-score metrics are provided for each class (0, 1, 2, 3).
#    - The model demonstrates high precision, recall, and F1-scores across all classes, indicating robust performance in classification.
#
# 3. **Confusion Matrix**:
#    - The confusion matrix shows the number of true positives, false positives, true negatives, and false negatives for each class.
#    - High values along the diagonal (true positives) and low values off the diagonal (false positives and false negatives) indicate accurate classification.
#
# 4. **Model Evaluation with Different Values of K**:
#    - The model is tested with different values of K (9, 11, 13, 15, 17).
#    - Accuracy remains consistently high for different values of K, ranging from 0.9762 to 0.9776.
#    - This suggests that the model's performance is robust and not highly sensitive to changes in the number of neighbors considered.
#
# 5. **Execution Time**:
#    - The execution time for training and testing the KNN model is relatively low, with the initial execution time being 60.2 ms.
#    - Subsequent executions with different values of K also maintain low execution times, indicating efficient model computation.
#
# Overall, the KNN model demonstrates excellent performance in accurately classifying the data with high precision, recall, and F1-scores across all classes. Additionally, the model exhibits robustness to changes in the number of neighbors considered and maintains efficient execution times, making it a suitable choice for classification tasks in various domains.

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC
from sklearn.utils.validation import column_or_1d

# Ensure the shape of the target variable is correct
df2_output_train = column_or_1d(df2_output_train)

# Initialize SVC classifier with linear kernel
classifier = SVC(kernel='linear', random_state=45032)

# Fit the classifier to the training data
classifier.fit(df2_inputs_train, df2_output_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cb4f03cd70e0> in <cell line: 5>()
#       3
#       4 # Ensure the shape of the target variable is correct
# ----> 5 df2_output_train = column_or_1d(df2_output_train)
#       6
#       7 # Initialize SVC classifier with linear kernel
#
# NameError: name 'df2_output_train' is not defined
# time: 333 ms (started: 2024-04-13 15:44:07 +00:00)
